# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
boston = pd.read_csv('boston_house_price.csv')

# %%
boston.shape
# Out:
# (369, 15)

# %%
boston.columns
# Out:
# Index(['HID', 'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
boston.head(25)
# Out:
#     HID     CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0     1  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1     2  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2     2  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 3     4  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 4     6  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 5     6  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 6     7  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 7     8  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 8     9  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 9    10  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 10   11  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# ...

# %%
boston[["HID","CRIM"]]
# Out:
#      HID     CRIM
# 0      1  0.00632
# 1      2  0.02731
# 2      2  0.02731
# 3      4  0.02729
# 4      6  0.03237
# ..   ...      ...
# 364  365  3.67822
# 365  366  4.22239
# 366  367  3.47428
# 367  368  4.55587
# 368  369  3.69695
#
# [369 rows x 2 columns]

# %%
boston.describe()
# Out:
#               HID        CRIM          ZN       INDUS        CHAS         NOX  \
# count  369.000000  368.000000  369.000000  369.000000  369.000000  369.000000
# mean   185.000000    0.517421   15.582656    8.613794    0.086721    0.516444
# std    106.665441    0.982998   26.086641    6.222847    0.281808    0.108948
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%     93.000000    0.057867    0.000000    3.970000    0.000000    0.437000
# 50%    185.000000    0.135705    0.000000    6.410000    0.000000    0.493000
# 75%    277.000000    0.466088   22.000000   10.590000    0.000000    0.544000
# max    369.000000    8.982960  100.000000   25.650000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  369.000000  369.000000  369.000000  369.000000  369.000000  369.000000
# mean     6.390593   61.201355    4.448298    5.040650  320.533875   17.809485
# ...

# %%
boston.hist(column='AGE', bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002D9AE916A48>]],
#       dtype=object)

# %%
###finding outliers


boston.boxplot(column='AGE', return_type='axes');

# %%
###  multivariate plot

###corelation find the relationship between the input variables

boston.corr()
# Out:
#               HID      CRIM        ZN     INDUS      CHAS       NOX        RM  \
# HID      1.000000  0.140632  0.221965 -0.101986  0.165616  0.014325  0.167055
# CRIM     0.140632  1.000000 -0.266101  0.539173  0.272865  0.738108 -0.212788
# ZN       0.221965 -0.266101  1.000000 -0.479191 -0.084517 -0.463827  0.294709
# INDUS   -0.101986  0.539173 -0.479191  1.000000  0.178554  0.702019 -0.370732
# CHAS     0.165616  0.272865 -0.084517  0.178554  1.000000  0.204781  0.056884
# NOX      0.014325  0.738108 -0.463827  0.702019  0.204781  1.000000 -0.261315
# RM       0.167055 -0.212788  0.294709 -0.370732  0.056884 -0.261315  1.000000
# AGE     -0.194211  0.433437 -0.536046  0.551880  0.159332  0.675400 -0.177602
# DIS      0.122274 -0.436683  0.629590 -0.614417 -0.183224 -0.711590  0.093024
# RAD      0.321108  0.694806 -0.171446  0.251513  0.242540  0.404425 -0.051571
# TAX      0.137895  0.673238 -0.150021  0.483267  0.133982  0.520810 -0.214879
# ...

# %%
#### preprocessing cleansing the data
# duplication
##return perfect duplicated
boston[boston.duplicated()]
# Out:
#    HID     CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 2    2  0.02731  0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 5    6  0.03237  0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
#
#    PTRATIO       B  LSTAT  MEDV
# 2     17.8  396.90   9.14  21.6
# 5     18.7  394.63   2.94  33.4

# %%
boston.head(10)
# Out:
#    HID     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 3    4  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 4    6  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 5    6  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 6    7  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 7    8  0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222
# 8    9  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# 9   10  0.14455  12.5   7.87     0  0.524  6.172  96.1  5.9505    5  311
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  396.90   9.14  21.6
# 3     17.8  392.83   4.03  34.7
# ...

# %%
##           lets drop duplicate


boston.drop_duplicates(inplace=True)

# %%
boston.shape
# Out:
# (367, 15)

# %%
## null handling

boston[boston.CRIM.isnull()]
# Out:
#     HID  CRIM   ZN  INDUS  CHAS    NOX    RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 22   23   NaN  0.0   8.14     0  0.538  5.57  98.1  3.7979    4  307     21.0
#
#          B  LSTAT  MEDV
# 22  376.57  21.02  13.6

# %%
#solution for null (replace with mean value)

boston['CRIM'].fillna(boston.CRIM.mean(), inplace=True)

# %%
boston[boston.CRIM.isnull()]
# Out:
# Empty DataFrame
# Columns: [HID, CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []

# %%
###uniqueness



boston.nunique().sort_values()
# Out:
# CHAS         2
# RAD          9
# ZN          26
# PTRATIO     45
# NOX         62
# TAX         63
# INDUS       73
# MEDV       186
# B          262
# DIS        277
# AGE        302
# LSTAT      331
# RM         340
# CRIM       366
# HID        367
# dtype: int64

# %%
boston.shape
# Out:
# (367, 15)

# %%
##drop the unique value
boston.drop(columns=["HID"], inplace=True )

# %%
boston.shape
# Out:
# (367, 14)

# %%
#split the data into train and test

# %%
from sklearn.model_selection import train_test_split

x_train, x_test,y_train,y_test=train_test_split(boston[boston.columns[~boston.columns.isin(["MEDV"])]],boston["MEDV"],test_size=0.33,random_state=5)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (245, 13)
# (122, 13)
# (245,)
# (122,)

# %%
###creating a odel

# %%
from sklearn.linear_model import LinearRegression

lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.intercept_
# Out:
# -11.935414178943372

# %%
lm.coef_
pd.DataFrame(zip(x_train.columns, lm.coef_.tolist()),columns=["names","coefficient"])
# Out:
#       names  coefficient
# 0      CRIM     0.589235
# 1        ZN     0.029112
# 2     INDUS    -0.006717
# 3      CHAS    -0.367708
# 4       NOX    -4.573508
# 5        RM     8.745103
# 6       AGE    -0.049417
# 7       DIS    -1.015238
# 8       RAD     0.339289
# 9       TAX    -0.015082
# 10  PTRATIO    -0.595622
# 11        B     0.013768
# 12    LSTAT    -0.112099

# %%
from sklearn.metrics import mean_squared_error
# model evaluation for training set
y_train_predict = lm.predict(x_train)
rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))


print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print("\n")

# model evaluation for testing set
y_test_predict = lm.predict(x_test)
rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))



print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 2.865575863915354
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 4.825116233335558
